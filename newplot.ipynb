# %% [markdown]
# This document is for producing plots. The numbers are copied from the model outputs.

# %%
import matplotlib.pyplot as plt
plt.xscale('log')
plt.ylim(0.55, 1.1)
ax = plt.gca()
ax.set_xticks([10,100,500])
ax.set_xticklabels([10,100,500])
plt.xlabel('Sample size N')

plt.plot([10,100,500], [0.9730,0.8036,0.8162], 'ro-')
plt.plot([10,100,500], [0.9288,0.8211,0.8464], 'bo-')


plt.legend(["LHM","MLHM"])
